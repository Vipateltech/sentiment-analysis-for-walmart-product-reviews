# %%
import pandas as pd
df = pd.read_csv("C:\\Users\\thinkpad\\Desktop\\project\\cleaned_data.csv")

# %%
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df
# Out:
#        Unnamed: 0                                              title  \
# 0               0                          Great TV for cord cutting
# 1               1                                        Frustrating
# 2               2                     1000 hours in, I give it an A+
# 3               3                                    Picture Perfect
# 4               4                              Amazing Versatile TV!
# ...           ...                                                ...
# 12570       12579  Amazon Prime stuck in Time Warp no Help from V...
# 12571       12580                               The picture is graet
# 12572       12581                                     Not too shabby
# 12573       12582                                 My first Vizio TV!
# 12574       12583                               Simple yet fabulous!
#
#              date  rating                                               text  \
# ...

# %%
plt.figure(figsize=(15,10))
sns.set(style = 'whitegrid')
total = float(len(df))
ax = sns.countplot(data = df, x='rating')

plt.title("Rating count for each product\n")
plt.ylabel("Count of ratings")
plt.xlabel("\nRatings")

for p in (ax.patches):
    cnt = p.get_height()
    x = p.get_x() + p.get_width()
    y = p.get_height()
    ax.annotate(cnt,(x,y),ha='center')

plt.show()

# %%
df
# Out:
#        Unnamed: 0                                              title  \
# 0               0                          Great TV for cord cutting
# 1               1                                        Frustrating
# 2               2                     1000 hours in, I give it an A+
# 3               3                                    Picture Perfect
# 4               4                              Amazing Versatile TV!
# ...           ...                                                ...
# 12570       12579  Amazon Prime stuck in Time Warp no Help from V...
# 12571       12580                               The picture is graet
# 12572       12581                                     Not too shabby
# 12573       12582                                 My first Vizio TV!
# 12574       12583                               Simple yet fabulous!
#
#              date  rating                                               text  \
# ...

# %%
from wordcloud import WordCloud, STOPWORDS

# %%
stopwords = set(STOPWORDS)
cloud_text = " ".join(i for i in df.cleaned_text)
wordcloud = WordCloud(width=800,height=500,random_state=10,max_font_size=100,stopwords=stopwords).generate(cloud_text)

plt.figure(figsize=(20,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
df['cleaned_title'] = df['cleaned_title'].fillna(" ")

# %%
df['cleaned_title_review'] = df['cleaned_title'].astype('string')+" "+df['cleaned_text']
df
# Out:
#        Unnamed: 0                                              title  \
# 0               0                          Great TV for cord cutting
# 1               1                                        Frustrating
# 2               2                     1000 hours in, I give it an A+
# 3               3                                    Picture Perfect
# 4               4                              Amazing Versatile TV!
# ...           ...                                                ...
# 12570       12579  Amazon Prime stuck in Time Warp no Help from V...
# 12571       12580                               The picture is graet
# 12572       12581                                     Not too shabby
# 12573       12582                                 My first Vizio TV!
# 12574       12583                               Simple yet fabulous!
#
#              date  rating                                               text  \
# ...

# %%
df['cleaned_title_review']=df['cleaned_title_review'].astype('string')

# %%
df.dtypes
# Out:
# Unnamed: 0               int64
# title                   object
# date                    object
# rating                   int64
# text                    object
# product                 object
# company                 object
# cleaned_text            object
# cleaned_title           object
# cleaned_title_review    string
# dtype: object

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                 0
# title                      0
# date                    1144
# rating                     0
# text                       0
# product                    0
# company                    0
# cleaned_text               0
# cleaned_title              0
# cleaned_title_review       0
# dtype: int64

# %%
stopwords = set(STOPWORDS)
stopwords.update(["tv"])
cloud_all_text = " ".join(i for i in df.cleaned_title_review)
wordcloud = WordCloud(stopwords=stopwords).generate(cloud_all_text)

plt.figure(figsize=(20,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
df["tag"] = df.rating.apply(lambda x: 'negative' if x < 3 else 'positive' if x > 3 else 'neutral')
df["tag"].value_counts()
# Out:
# positive    9056
# negative    2901
# neutral      618
# Name: tag, dtype: int64

# %%
df
# Out:
#        Unnamed: 0                                              title  \
# 0               0                          Great TV for cord cutting
# 1               1                                        Frustrating
# 2               2                     1000 hours in, I give it an A+
# 3               3                                    Picture Perfect
# 4               4                              Amazing Versatile TV!
# ...           ...                                                ...
# 12570       12579  Amazon Prime stuck in Time Warp no Help from V...
# 12571       12580                               The picture is graet
# 12572       12581                                     Not too shabby
# 12573       12582                                 My first Vizio TV!
# 12574       12583                               Simple yet fabulous!
#
#              date  rating                                               text  \
# ...

# %%
stopwords = set(STOPWORDS)
stopwords.update(["tv"]) 

pos_words=" ".join([i for i in df['cleaned_title_review'][df['tag']=="positive"]])
wordcloud_pos = WordCloud(stopwords=stopwords).generate(pos_words)

plt.figure(figsize=(20,10))
plt.imshow(wordcloud_pos, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
neg_words=" ".join([i for i in df['cleaned_title_review'][df['tag']=="negative"]])
wordcloud_neg = WordCloud(stopwords=stopwords).generate(neg_words)

plt.figure(figsize=(20,10))
plt.imshow(wordcloud_neg, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
neu_words=" ".join([i for i in df['cleaned_title_review'][df['tag']=="neutral"]])
wordcloud_neu = WordCloud(stopwords=stopwords).generate(neu_words)

plt.figure(figsize=(20,10))
plt.imshow(wordcloud_neu, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
df.to_csv("dataframe_tag.csv")

# %%
from powerbiclient import Report, models

# %%
from powerbiclient.authentication import DeviceCodeLoginAuthentication

# %%
device_auth = DeviceCodeLoginAuthentication()
# Out:
# Performing interactive authentication. Please follow the instructions on the terminal.
#  To sign in, use a web browser to open the page https://microsoft.com/devicelogin and enter the code FE4F7YNNJ to authenticate.
# You have logged in.
# Interactive authentication successfully completed.

# %%
group_id = "e236c0d9-e2c7-4f55-94eb-c9457ca78ad8"
report_id = "0b9f94ff-4050-49fd-9e49-f5ab434e0a9b"

# %%
report = Report(group_id = group_id, report_id = report_id, auth = device_auth)
report
# Out:
# Report()
